# %% [markdown]
# # ASTR3110 Computer Laboratory 3: Classifying Images using Artificial and Convolutional Neural Networks.
#
# Intro to CORNISH
#
# In the first part of the lab, you will ... learn your data, prepare data for input into a ANN, run a ANN classifer, run tests to determine how well your classifier has performed, tweak parameters to see if you can improve performance.
#
# In the second part of the lab, you will ... use a CNN on 3 images per source in order to
#
# Finally, you will...
#
# At the completion of this lab, you will have acquired (or improved) the following skills:

# %% [markdown]
# # Part 1: ANNs

# %% [markdown]
# ## Getting to know the data

# %% [markdown]
# ## Preparing the data

# %% [markdown]
# ## Running the ANN

# %% [markdown]
# ## Quantifying the performance

# %% [markdown]
# # <font color=red>You should aim to get to here by the end of the first week of this lab!</font>

# %% [markdown]
# # Part 2: CNNs

# %% [markdown]
# ## Preparing the data

# %% [markdown]
# ## Running the CNN

# %% [markdown]
# ## Evaluate the performance of the CNN

# %% [markdown]
# ## Tweak the CNN to improve performance
