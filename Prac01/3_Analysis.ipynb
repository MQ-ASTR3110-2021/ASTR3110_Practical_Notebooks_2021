# %% [markdown]
# # Part 3: Analysis of the period-luminosity relation
#
# This lab will be a little different to previous ones:
#
# * *You* will be driving the work - all based on the code from previous tutorials
# * You will need to submit a Jupyter-Notebook by the **Friday April 24th**, which will be marked.
# * Your submission will be marked based on comments you embed into the code. You will need to fully explain the code your used, why you choose to do the analysis a certain way, what plots you made and why. You will also be marked on the formatting of your code (easy to understand, sensible variable names etc), and plots (labeled axes, well-formatted).
#
# Please work on the following tasks:

# %% [markdown]
# ## Final filtering of data

# %%
# Final filtering of data before fit

# %% [markdown]
# ## Fitting a straight line relation to the period-luminosity data
#
# Choose one of the dataset and do the following:

# %%
# Function for a straigh line to be used with a fitter

# %%
# Function to calculate the log-likelihood of the model

# %%
# Run a simple fit using an optimiser

# %%
# Run a fit using MCMC

# %%
# Read off the values and errors from MCMC chains

# %% [markdown]
# Now do the MCMC fit for the other dataset

# %%
# Repeat all above for other datase

# %% [markdown]
# ## Compare the two datasets and fits
#
# Compare the scatter between the two datasets: is there a difference in scatter for the two distance estimates and what does that mean? Try this for a few different SN cuts to determine what S/N cut in parallax might be appropriate. What biases might these cuts introduce? Comment on scatter overall -- causes (intrinsic uncertainty in distance and magnitude, dust, source mischaracterisation)?

# %%
# Your code, plots and analysis here.

# %% [markdown]
# ## Analysis of the LMC
#
# Select all delta cepheids in the LMC using a box l=(273-285) , b=(-38, -28). Use their calibrated P-L relation to determine the distance to the LMC.
# * Use the PL to determine the luminosity for each cepheid, then determine its distance.
# * Determine the distance to LMC as the mean/median and use the stdev/percentiles to get a measure of uncertainty.  * Would it be possible to use parallaxes to determine distance to LMC?

# %%
# Your code here

# %% [markdown]
# ## Stretch goals - demonstrate the use of a prior on the fit
#
# Ask Cormac.
